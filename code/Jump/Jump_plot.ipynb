# %% [markdown]
# # Plot for Jump according to Oosterlee's book

# %%
import merton_jump_cos_density_paths

# %%
import merton_jump_pdf_cdf_parameter_effects

# %%
import merton_jump_implied_vol_cos

# %%
import kou_jump_implied_vol_cos

# %%
import merton_kou_bs_delta_hedge_coarse_grid
# Out:
# /Users/tyau/Desktop/cornell course/spring/ORIE 5610 Stochastic cal/project/code/Jump/merton_kou_bs_delta_hedge_coarse_grid.py:113: RuntimeWarning: divide by zero encountered in divide
#   d1    = (np.log(S_0 / K) + (r + 0.5 * np.power(sigma,2.0)) * \
# /Users/tyau/Desktop/cornell course/spring/ORIE 5610 Stochastic cal/project/code/Jump/merton_kou_bs_delta_hedge_coarse_grid.py:97: RuntimeWarning: invalid value encountered in sqrt
#   * (T-t)) / (sigma * np.sqrt(T-t))
# /Users/tyau/Desktop/cornell course/spring/ORIE 5610 Stochastic cal/project/code/Jump/merton_kou_bs_delta_hedge_coarse_grid.py:98: RuntimeWarning: invalid value encountered in sqrt
#   d2    = d1 - sigma * np.sqrt(T-t)
# Merton — path 10, S0=1.0, PnL(T-)=-1.2394349410560281, S(T)=1.5434482515843373, max(S(T)-K,0)=[0.59344825], PnL(T)=-0.29067499592117896
# Kou    — path 10, S0=1.0, PnL(T-)=-0.00133931608573002, S(T)=0.8564777938219603, max(S(T)-K,0)=[0.], PnL(T)=-0.0013406542933860647

# %%
import merton_kou_bs_delta_hedge_fine_grid_high_lambda
# Out:
# Merton — path 10, S0=1.0, PnL(T-)=-0.2403640906177714, S(T)=0.5950092216299782, max(S(T)-K,0)=[0.], PnL(T)=-0.24037610912276242
# Kou    — path 10, S0=1.0, PnL(T-)=-0.20943945273403097, S(T)=0.8165393296814979, max(S(T)-K,0)=[0.], PnL(T)=-0.20944992496847137
