# %% [markdown]
# # Heston model

# %%
import CIR_ExactSimulation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import CIR_ExactSimulation
#
# File ~/Desktop/cornell course/spring/ORIE 5610 Stochastic cal/project/code/heston/CIR_ExactSimulation.py:128
#     125     for i in range(0,len(NoOfStepsV)):
#     126         print("AES Scheme, K ={0}, dt = {1} = {2}".format(K,dtV[i],errorAES[i]))
# --> 128 mainCalculation()
#
# File ~/Desktop/cornell course/spring/ORIE 5610 Stochastic cal/project/code/heston/CIR_ExactSimulation.py:69, in mainCalculation()
#      66 K = np.linspace(0.1,S_0*2.0,30)
#      68 # Exact solution with the COS method
# ---> 69 cf = ChFHestonModel(r,T,kappa,gamma,vbar,v0,rho)
#      71 # The COS method
#      72 optValueExact = CallPutOptionPriceCOSMthd(cf, CP, S_0, r, T, K, 1000, 8)
#
# NameError: name 'ChFHestonModel' is not defined

# %%
import CIR_paths_boundary

# %%
import CIR_paths_Exact

# %%
import CorrelatedBM

# %%
import HestonModelDiscretization
# Out:
# Euler Scheme, K =[140.], dt = 1.0 = [1.30476871]
# Euler Scheme, K =[140.], dt = 0.25 = [0.54404403]
# Euler Scheme, K =[140.], dt = 0.125 = [0.1720427]
# Euler Scheme, K =[140.], dt = 0.0625 = [0.08078707]
# Euler Scheme, K =[140.], dt = 0.03125 = [0.01260589]
# Euler Scheme, K =[140.], dt = 0.015625 = [0.00605332]
# AES Scheme, K =[140.], dt = 1.0 = [0.00800533]
# AES Scheme, K =[140.], dt = 0.25 = [0.00985109]
# AES Scheme, K =[140.], dt = 0.125 = [0.00135139]
# AES Scheme, K =[140.], dt = 0.0625 = [0.00661993]
# AES Scheme, K =[140.], dt = 0.03125 = [0.0157029]
# AES Scheme, K =[140.], dt = 0.015625 = [0.00699352]

# %%
import OptionPrices_EulerAndMilstein
# Out:
# EUROPEAN OPTION PRICING
# Exact option price = [0.73585362]
# For N = 100 Euler scheme yields option price = 0.728554761255097 and Milstein 0.728444051871542
# For N = 100 Euler error = [-0.00729886] and Milstein  error [-0.00740957]
# For N = 1000 Euler scheme yields option price = 0.7200580888738554 and Milstein 0.7202098357606095
# For N = 1000 Euler error = [-0.01579553] and Milstein  error [-0.01564379]
# For N = 5000 Euler scheme yields option price = 0.7481360160804368 and Milstein 0.7481404588408821
# For N = 5000 Euler error = [0.0122824] and Milstein  error [0.01228684]
# For N = 10000 Euler scheme yields option price = 0.7387184512149808 and Milstein 0.7386727436156081
# For N = 10000 Euler error = [0.00286483] and Milstein  error [0.00281912]
# CASH OR NOTHING PRICING
# Exact option price = [[2.44829963]]
# For N = 100 Euler scheme yields option price = 2.731117147394321 and Milstein 2.731117147394321
# ...
