# %% [markdown]
# # Reference code for generating paths of different processes
# - GBM_ABM_paths: Geometric Brownian Motion and Arithmetic Brownian Motion
# - GBM_ABM_paths_Martingale: GBM and Arithmetic Brownian Motion under martingale measure
# - PathsUnderQandPmeasure: Paths under Q and P measure
# - MertonProcess_paths: Merton Jump Diffusion Process
# - PoissonProcess_paths: Poisson Process and Compensated Poisson Process

# %%
import GBM_ABM_paths
import GBM_ABM_paths_Martingale
import PathsUnderQandPmeasure
import MertonProcess_paths
import PoissonProcess_paths

# %%
from GBM_ABM_paths import mainCalculation

NoOfPaths = 25
NoOfSteps = 500
T = 1
r = 0.05
sigma = 0.4
S_0 = 100

mainCalculation(NoOfPaths, NoOfSteps, T, r, sigma, S_0)

# %%
from GBM_ABM_paths_Martingale import mainCalculation

NoOfPaths = 25
NoOfSteps = 500
T = 1
r = 0.05
sigma = 0.4
S_0 = 100

mainCalculation(NoOfPaths, NoOfSteps, T, r, sigma, S_0)
# Out:
# 105.99110328167617
# 100.82185617682455

# %%
from MertonProcess_paths import mainCalculation

NoOfPaths = 25
NoOfSteps = 500
T = 5
xiP = 1
muJ = 0
sigmaJ = 0.7
sigma = 0.2

S0 =100
r=0.05
mainCalculation(NoOfPaths, NoOfSteps, T, xiP, muJ, sigmaJ, sigma, S0, r)

# %%
from MertonProcess_paths import mainCalculation

NoOfPaths = 25
NoOfSteps = 500
T = 5
xiP = 1
muJ = 0
sigmaJ = 0.7
sigma = 0.2

S0 =100
r=0.05
mainCalculation(NoOfPaths, NoOfSteps, T, xiP, muJ, sigmaJ, sigma, S0, r)

# %%
from PoissonProcess_paths import mainCalculation

NoOfPaths = 25
NoOfSteps = 500
T = 5
xiP = 1
mainCalculation(NoOfPaths, NoOfSteps, T, xiP)
